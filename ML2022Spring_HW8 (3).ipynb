# %% [markdown]
# # **Homework 8 - Anomaly Detection**
#
# If there are any questions, please contact mlta-2022spring-ta@googlegroups.com
#
# Slide:    [Link]()　Kaggle: [Link](https://www.kaggle.com/c/ml2022spring-hw8)

# %% [markdown]
# # Set up the environment

# %% [markdown]
# ## Package installation

# %%
# Training progress bar
# !pip install -q qqdm
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 74.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.1 MB/s eta 0:00:00
#   Building wheel for qqdm (setup.py) ... done

# %% [markdown]
# ## Downloading data

# %%
#失效了
#!wget https://github.com/MachineLearningHW/HW8_Dataset/releases/download/v1.0.0/data.zip
from google.colab import drive
drive.mount('/content/drive')

# 复制到当前目录并改名为 data.zip
# !cp "/content/drive/MyDrive/data.zip" ./data.zip

# 用 unzip 解压
#!unzip -q ./data.zip -d
# !unzip -q ./data.zip -d ./
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import packages

# %%
import random
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler, TensorDataset
import torchvision.transforms as transforms
import torch.nn.functional as F
from torch.autograd import Variable
import torchvision.models as models
from torch.optim import Adam, AdamW
from qqdm import qqdm, format_str
import pandas as pd

# %% [markdown]
# # Loading data

# %%
train = np.load('data/trainingset.npy', allow_pickle=True)
test = np.load('data/testingset.npy', allow_pickle=True)

print(train.shape)
print(test.shape)
# Out:
# (100000, 64, 64, 3)
# (19636, 64, 64, 3)

# %% [markdown]
# ## Random seed
# Set the random seed to a certain value for reproducibility.

# %%
def same_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

same_seeds(48763)

# %% [markdown]
# # Autoencoder

# %% [markdown]
# # Models & loss

# %%
#Multi-encoder autoencoder base on FCN
import torch
import torch.nn as nn

class MLPBranch(nn.Module):
    def __init__(self, in_dim, hidden_dims, out_dim):
        super().__init__()
        layers, prev = [], in_dim
        for h in hidden_dims:
            layers += [nn.Linear(prev, h), nn.ReLU()]
            prev = h
        layers += [nn.Linear(prev, out_dim)]
        self.net = nn.Sequential(*layers)
    def forward(self, x): return self.net(x)

class MultiEncoderFCNAE(nn.Module):

    def __init__(self, input_dim=64*64*3, z_dim=64):
        super().__init__()
        self.enc_a = MLPBranch(input_dim, [2048, 512, 128,64], out_dim=64)
        self.enc_b = MLPBranch(input_dim, [128, 64, 12,3], out_dim=3)

        # 融合到统一 latent
        self.fuse = nn.Sequential(
            nn.LayerNorm(256),
            nn.ReLU(),
            nn.Linear(256, z_dim)
        )

        self.decoder = nn.Sequential(
            nn.Linear(z_dim, 128), nn.ReLU(),
            nn.Linear(128, 512),   nn.ReLU(),
            nn.Linear(512, 2048),  nn.ReLU(),
            nn.Linear(2048, input_dim),
            nn.Tanh()
        )

    def encode(self, x):
        a = self.enc_a(x)                 # (B,128)
        b = self.enc_b(x)                 # (B,128)
        h = torch.cat([a, b], dim=-1)     # (B,256)
        z = self.fuse(h)                  # (B,z_dim)
        return z

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        z = self.encode(x)
        x = self.decode(z)
        return x

# %%
class fcn_autoencoder(nn.Module):
    def __init__(self):
        super(fcn_autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(64 * 64 * 3, 2048),#128
            nn.ReLU(),
            nn.Linear(2048, 512),#64
            nn.ReLU(),
            nn.Linear(512, 128),#12
            nn.ReLU(),
            nn.Linear(128, 64)#3
        )

        self.decoder = nn.Sequential(
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, 512),
            nn.ReLU(),
            nn.Linear(512, 2048),
            nn.ReLU(),
            nn.Linear(2048, 64 * 64 * 3),
            nn.Tanh()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

class conv_autoencoder(nn.Module):
    def __init__(self):
        super(conv_autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 12, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(12, 24, 4, stride=2, padding=1),
            nn.ReLU(),
			      nn.Conv2d(24, 48, 4, stride=2, padding=1),
            nn.ReLU(),
        )
        self.decoder = nn.Sequential(
			      nn.ConvTranspose2d(48, 24, 4, stride=2, padding=1),
            nn.ReLU(),
			      nn.ConvTranspose2d(24, 12, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(12, 3, 4, stride=2, padding=1),
            nn.Tanh(),
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x


class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        self.encoder = nn.Sequential(
            #输入通道 输出通道 卷积核大小n*n out=⌊input+2p−k​⌋/s+1
            nn.Conv2d(3, 12, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(12, 24, 4, stride=2, padding=1),
            nn.ReLU(),
        )
        self.enc_out_1 = nn.Sequential(
            nn.Conv2d(24, 48, 4, stride=2, padding=1),
            nn.ReLU(),
        )
        self.enc_out_2 = nn.Sequential(
            nn.Conv2d(24, 48, 4, stride=2, padding=1),
            nn.ReLU(),
        )
        self.decoder = nn.Sequential(
			      nn.ConvTranspose2d(48, 24, 4, stride=2, padding=1),
            nn.ReLU(),
			      nn.ConvTranspose2d(24, 12, 4, stride=2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(12, 3, 4, stride=2, padding=1),
            nn.Tanh(),
        )

    def encode(self, x):
        h1 = self.encoder(x)
        return self.enc_out_1(h1), self.enc_out_2(h1)

    def reparametrize(self, mu, logvar):
        std = logvar.mul(0.5).exp_()
        if torch.cuda.is_available():
            eps = torch.cuda.FloatTensor(std.size()).normal_()
        else:
            eps = torch.FloatTensor(std.size()).normal_()
        eps = Variable(eps)
        return eps.mul(std).add_(mu)

    def decode(self, z):
        return self.decoder(z)

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparametrize(mu, logvar)
        return self.decode(z), mu, logvar


def loss_vae(recon_x, x, mu, logvar, criterion):
    """
    recon_x: generating images
    x: origin images
    mu: latent mean
    logvar: latent log variance
    """
    mse = criterion(recon_x, x)
    KLD_element = mu.pow(2).add_(logvar.exp()).mul_(-1).add_(1).add_(logvar)
    KLD = torch.sum(KLD_element).mul_(-0.5)
    return mse + KLD

# %% [markdown]
# # Dataset module
#
# Module for obtaining and processing data. The transform function here normalizes image's pixels from [0, 255] to [-1.0, 1.0].

# %%
class CustomTensorDataset(TensorDataset):
    """TensorDataset with support of transforms.
    """
    def __init__(self, tensors):
        self.tensors = tensors
        if tensors.shape[-1] == 3:
            self.tensors = tensors.permute(0, 3, 1, 2)

        self.transform = transforms.Compose([
          transforms.Lambda(lambda x: x.to(torch.float32)),
          transforms.Lambda(lambda x: 2. * x/255. - 1.),
        ])

    def __getitem__(self, index):
        x = self.tensors[index]

        if self.transform:
            # mapping images to [-1.0, 1.0]
            x = self.transform(x)

        return x

    def __len__(self):
        return len(self.tensors)

# %% [markdown]
# # Training

# %% [markdown]
# ## Configuration

# %%
# Training hyperparameters
num_epochs = 50
batch_size = 2000
learning_rate = 1e-3

# Build training dataloader
x = torch.from_numpy(train)
train_dataset = CustomTensorDataset(x)

train_sampler = RandomSampler(train_dataset)
train_dataloader = DataLoader(train_dataset, sampler=train_sampler, batch_size=batch_size)

# Model
model_type = 'fcn'   # selecting a model type from {'cnn', 'fcn', 'vae', 'resnet'}
model_classes = {'fcn': fcn_autoencoder(), 'cnn': conv_autoencoder(), 'vae': VAE(),'multi':MultiEncoderFCNAE(input_dim=64*64*3, z_dim=64)}
model = model_classes[model_type].cuda()

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# ## Training loop

# %%
best_loss = np.inf
model.train()

qqdm_train = qqdm(range(num_epochs), desc=format_str('bold', 'Description'))
for epoch in qqdm_train:
    tot_loss = list()
    for data in train_dataloader:

        # ===================loading=====================
        img = data.float().cuda()
        if model_type in ['fcn','multi']:
            img = img.view(img.shape[0], -1)

        # ===================forward=====================
        output = model(img)
        if model_type in ['vae']:
            loss = loss_vae(output[0], img, output[1], output[2], criterion)
        else:
            loss = criterion(output, img)

        tot_loss.append(loss.item())
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # ===================save_best====================
    mean_loss = np.mean(tot_loss)
    if mean_loss < best_loss:
        best_loss = mean_loss
        torch.save(model, 'best_model_{}.pt'.format(model_type))
    # ===================log========================
    qqdm_train.set_infos({
        'epoch': f'{epoch + 1:.0f}/{num_epochs:.0f}',
        'loss': f'{mean_loss:.4f}',
    })
    # ===================save_last========================
    torch.save(model, 'last_model_{}.pt'.format(model_type))
# Out:
#  Iters    Elapsed Time      Speed
#  0/50           -             -
# Description   0.0% |                                                           | Iters    Elapsed Time      Speed    epoch   loss
#  1/50   00:00:14<00:11:27  0.07it/s  1/50   0.1994
# Description   2.0% |█                                                          | Iters    Elapsed Time      Speed    epoch   loss
#  2/50   00:00:27<00:10:59  0.07it/s  2/50   0.1307
# Description   4.0% |██                                                         | Iters    Elapsed Time      Speed    epoch   loss
#  3/50   00:00:40<00:10:42  0.07it/s  3/50   0.1023
# Description   6.0% |███                                                        | Iters    Elapsed Time      Speed    epoch   loss
#  4/50   00:00:57<00:11:00  0.07it/s  4/50   0.0897
# Description   8.0% |████                                                       | Iters    Elapsed Time      Speed    epoch   loss
#  5/50   00:01:11<00:10:40  0.07it/s  5/50   0.0822
# Description  10.0% |█████                                                      | Iters    Elapsed Time      Speed    epoch   loss
#  6/50   00:01:24<00:10:22  0.07it/s  6/50   0.0767
# Description  12.0% |███████                                                    | Iters    Elapsed Time      Speed    epoch   loss
#  7/50   00:01:38<00:10:05  0.07it/s  7/50   0.0725
# Description  14.0% |████████                                                   | Iters    Elapsed Time      Speed    epoch   loss
#  8/50   00:01:52<00:09:49  0.07it/s  8/50   0.0683
# Description  16.0% |█████████                                                  | Iters    Elapsed Time      Speed    epoch   loss
#  9/50   00:02:05<00:09:33  0.07it/s  9/50   0.0665
# Description  18.0% |██████████                                                 | Iters    Elapsed Time      Speed    epoch   loss
#  10/50  00:02:21<00:09:25  0.07it/s  10/50  0.0652
# Description  20.0% |███████████                                                | Iters    Elapsed Time      Speed    epoch   loss
#  11/50  00:02:35<00:09:10  0.07it/s  11/50  0.0628
# Description  22.0% |████████████                                               | Iters    Elapsed Time      Speed    epoch   loss
#  12/50  00:02:50<00:08:59  0.07it/s  12/50  0.0608
# Description  24.0% |██████████████                                             | Iters    Elapsed Time      Speed    epoch   loss
#  13/50  00:03:04<00:08:45  0.07it/s  13/50  0.0607
# Description  26.0% |███████████████                                            | Iters    Elapsed Time      Speed    epoch   loss
#  14/50  00:03:19<00:08:31  0.07it/s  14/50  0.0593
# Description  28.0% |████████████████                                           | Iters    Elapsed Time      Speed    epoch   loss
#  15/50  00:03:33<00:08:18  0.07it/s  15/50  0.0571
# Description  30.0% |█████████████████                                          | Iters    Elapsed Time      Speed    epoch   loss
#  16/50  00:03:48<00:08:04  0.07it/s  16/50  0.0556
# Description  32.0% |██████████████████                                         | Iters    Elapsed Time      Speed    epoch   loss
#  17/50  00:04:02<00:07:50  0.07it/s  17/50  0.0565
# Description  34.0% |████████████████████                                       | Iters    Elapsed Time      Speed    epoch   loss
#  18/50  00:04:16<00:07:36  0.07it/s  18/50  0.0547
# Description  36.0% |█████████████████████                                      | Iters    Elapsed Time      Speed    epoch   loss
#  19/50  00:04:32<00:07:25  0.07it/s  19/50  0.0536
# Description  38.0% |██████████████████████                                     | Iters    Elapsed Time      Speed    epoch   loss
#  20/50  00:04:47<00:07:10  0.07it/s  20/50  0.0519
# Description  40.0% |███████████████████████                                    | Iters    Elapsed Time      Speed    epoch   loss
#  21/50  00:05:00<00:06:55  0.07it/s  21/50  0.0520
# Description  42.0% |████████████████████████                                   | Iters    Elapsed Time      Speed    epoch   loss
#  22/50  00:05:14<00:06:39  0.07it/s  22/50  0.0523
# Description  44.0% |█████████████████████████                                  | Iters    Elapsed Time      Speed    epoch   loss
#  23/50  00:05:28<00:06:25  0.07it/s  23/50  0.0507
# Description  46.0% |███████████████████████████                                | Iters    Elapsed Time      Speed    epoch   loss
#  24/50  00:05:42<00:06:11  0.07it/s  24/50  0.0499
# Description  48.0% |████████████████████████████                               | Iters    Elapsed Time      Speed    epoch   loss
#  25/50  00:05:57<00:05:57  0.07it/s  25/50  0.0494
# Description  50.0% |█████████████████████████████                              | Iters    Elapsed Time      Speed    epoch   loss
#  26/50  00:06:11<00:05:43  0.07it/s  26/50  0.0489
# Description  52.0% |██████████████████████████████                             | Iters    Elapsed Time      Speed    epoch   loss
#  27/50  00:06:25<00:05:28  0.07it/s  27/50  0.0502
# Description  54.0% |███████████████████████████████                            | Iters    Elapsed Time      Speed    epoch   loss
#  28/50  00:06:41<00:05:15  0.07it/s  28/50  0.0486
# Description  56.0% |█████████████████████████████████                          | Iters    Elapsed Time      Speed    epoch   loss
#  29/50  00:06:56<00:05:01  0.07it/s  29/50  0.0477
# Description  58.0% |██████████████████████████████████                         | Iters    Elapsed Time      Speed    epoch   loss
#  30/50  00:07:12<00:04:48  0.07it/s  30/50  0.0477
# Description  60.0% |███████████████████████████████████                        | Iters    Elapsed Time      Speed    epoch   loss
#  31/50  00:07:26<00:04:33  0.07it/s  31/50  0.0477
# Description  62.0% |████████████████████████████████████                       | Iters    Elapsed Time      Speed    epoch   loss
#  32/50  00:07:40<00:04:19  0.07it/s  32/50  0.0468
# Description  64.0% |█████████████████████████████████████                      | Iters    Elapsed Time      Speed    epoch   loss
#  33/50  00:07:54<00:04:04  0.07it/s  33/50  0.0463
# Description  66.0% |██████████████████████████████████████                     | Iters    Elapsed Time      Speed    epoch   loss
#  34/50  00:08:09<00:03:50  0.07it/s  34/50  0.0459
# Description  68.0% |████████████████████████████████████████                   | Iters    Elapsed Time      Speed    epoch   loss
#  35/50  00:08:23<00:03:35  0.07it/s  35/50  0.0459
# Description  70.0% |█████████████████████████████████████████                  | Iters    Elapsed Time      Speed    epoch   loss
#  36/50  00:08:36<00:03:20  0.07it/s  36/50  0.0459
# Description  72.0% |██████████████████████████████████████████                 | Iters    Elapsed Time      Speed    epoch   loss
#  37/50  00:08:51<00:03:06  0.07it/s  37/50  0.0454
# Description  74.0% |███████████████████████████████████████████                | Iters    Elapsed Time      Speed    epoch   loss
#  38/50  00:09:05<00:02:52  0.07it/s  38/50  0.0452
# Description  76.0% |████████████████████████████████████████████               | Iters    Elapsed Time      Speed    epoch   loss
#  39/50  00:09:20<00:02:38  0.07it/s  39/50  0.0443
# Description  78.0% |██████████████████████████████████████████████             | Iters    Elapsed Time      Speed    epoch   loss
#  40/50  00:09:33<00:02:23  0.07it/s  40/50  0.0447
# Description  80.0% |███████████████████████████████████████████████            | Iters    Elapsed Time      Speed    epoch   loss
#  41/50  00:09:47<00:02:08  0.07it/s  41/50  0.0443
# Description  82.0% |████████████████████████████████████████████████           | Iters    Elapsed Time      Speed    epoch   loss
#  42/50  00:10:00<00:01:54  0.07it/s  42/50  0.0444
# Description  84.0% |█████████████████████████████████████████████████          | Iters    Elapsed Time      Speed    epoch   loss
#  43/50  00:10:15<00:01:40  0.07it/s  43/50  0.0439
# Description  86.0% |██████████████████████████████████████████████████         | Iters    Elapsed Time      Speed    epoch   loss
#  44/50  00:10:29<00:01:25  0.07it/s  44/50  0.0430
# Description  88.0% |███████████████████████████████████████████████████        | Iters    Elapsed Time      Speed    epoch   loss
#  45/50  00:10:43<00:01:11  0.07it/s  45/50  0.0438
# Description  90.0% |█████████████████████████████████████████████████████      | Iters    Elapsed Time      Speed    epoch   loss
#  46/50  00:10:57<00:00:57  0.07it/s  46/50  0.0429
# Description  92.0% |██████████████████████████████████████████████████████     | Iters    Elapsed Time      Speed    epoch   loss
#  47/50  00:11:10<00:00:42  0.07it/s  47/50  0.0430
# Description  94.0% |███████████████████████████████████████████████████████    | Iters    Elapsed Time      Speed    epoch   loss
#  48/50  00:11:26<00:00:28  0.07it/s  48/50  0.0429
# Description  96.0% |████████████████████████████████████████████████████████   | Iters    Elapsed Time      Speed    epoch   loss
#  49/50  00:11:40<00:00:14  0.07it/s  49/50  0.0427
# Description  98.0% |█████████████████████████████████████████████████████████  | Iters    Elapsed Time      Speed    epoch   loss
#  50/50  00:11:54<00:00:00  0.07it/s  50/50  0.0425
# Description 100.0% |███████████████████████████████████████████████████████████| Iters    Elapsed Time      Speed    epoch   loss
#  50/50  00:11:54<00:00:00  0.07it/s  50/50  0.0425
# Description 100.0% |███████████████████████████████████████████████████████████|

# %% [markdown]
# # Inference
# Model is loaded and generates its anomaly score predictions.

# %% [markdown]
# ## Initialize
# - dataloader
# - model
# - prediction file

# %%
eval_batch_size = 200

# build testing dataloader
data = torch.tensor(test, dtype=torch.float32)
test_dataset = CustomTensorDataset(data)
test_sampler = SequentialSampler(test_dataset)
test_dataloader = DataLoader(test_dataset, sampler=test_sampler, batch_size=eval_batch_size, num_workers=1)
eval_loss = nn.MSELoss(reduction='none')

# load trained model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
checkpoint_path = f'last_model_{model_type}.pt'
#model = torch.load(checkpoint_path)
model = torch.load(checkpoint_path, map_location=device, weights_only=False)
#model.eval()
model = model.to(device).eval()
# prediction file
out_file = 'prediction.csv'

# %%
anomality = list()
with torch.no_grad():
  for i, data in enumerate(test_dataloader):
    img = data.float().cuda()
    if model_type in ['fcn','multi']:
      img = img.view(img.shape[0], -1)
    output = model(img)
    if model_type in ['vae']:
      output = output[0]
    if model_type in ['fcn','multi']:
        loss = eval_loss(output, img).sum(-1)
    else:
        loss = eval_loss(output, img).sum([1, 2, 3])
    anomality.append(loss)
anomality = torch.cat(anomality, axis=0)
anomality = torch.sqrt(anomality).reshape(len(test), 1).cpu().numpy()

df = pd.DataFrame(anomality, columns=['score'])
df.to_csv(out_file, index_label = 'ID')
